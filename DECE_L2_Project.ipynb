# %% [markdown]
# <a href="https://colab.research.google.com/github/amr-kzf/NEXT-City/blob/main/DECE_L2_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from rich.console import Console
console = Console()
# بيانات الحجوزات للخدمة الأولى
new_car_id = [
    ["13-04-2025", "Sunday", [6, 10, 1, 10, 7]],
    ["14-04-2025", "Monday", [10, 2, 10, 6, 4]],
    ["15-04-2025", "Tuesday", [3, 1, 10, 10, 9]],
    ["16-04-2025", "Wednesday", [10, 8, 10, 7, 3]],
    ["17-04-2025", "Thursday", [2, 10, 4, 10, 1]]
]

# حساب المتوسط
def calculate_mean(service_data):
    total_reservations = sum([sum(day[2]) for day in service_data])
    total_slots = len(service_data) * len(service_data[0][2])
    mean = total_reservations / total_slots
    return mean

mean_service1 = calculate_mean(new_car_id)
print(f"Mean of reservations for Service#1: {mean_service1:.2f}")

# إيجاد اليوم الأكثر ازدحامًا
def most_crowded_day(service_data):
    totals = [sum(day[2]) for day in service_data]
    max_total = max(totals)
    max_index = totals.index(max_total)
    return service_data[max_index][1], max_total

# إيجاد اليوم الأقل ازدحامًا
def least_crowded_day(service_data):
    totals = [sum(day[2]) for day in service_data]
    min_total = min(totals)
    min_index = totals.index(min_total)
    return service_data[min_index][1], min_total

most_crowded, max_reservations = most_crowded_day(new_car_id)
least_crowded, min_reservations = least_crowded_day(new_car_id)

print(f"Most Crowded Day for Service#1: {most_crowded} with {max_reservations} reservations")
print(f"Least Crowded Day for Service#1: {least_crowded} with {min_reservations} reservations")

# التحقق من قوة كلمة المرور
def is_strong_password(password):
    if len(password) != 8:
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    return True

# تسجيل المستخدم
def register_user():
    console.print("🎉 Welcome to the Booking Management System! 🎉", style="bold green")
    username = input("👤 Enter your username: ")
    while True:
        password = input("🔒 Enter a strong password (8 characters, mix of upper and lower case): ")
        if is_strong_password(password):
            confirm_password = input("🔑 Confirm your password: ")
            if password == confirm_password:
                print("✅ Successful Registration! 🎉")
                return username, password
            else:
                print("❌ Passwords mismatched, please try again.")
        else:
            print("⚠️ Weak password, please try again.")

# تسجيل الدخول
def login_user(registered_username, registered_password):
    print("🔐 Please log in")
    while True:
        username = input("👤 Enter your username: ")
        password = input("🔒 Enter your password: ")
        if username == registered_username and password == registered_password:
            print(f"🎉 Welcome {username}! 🎉")
            return True
        else:
            print("❌ Incorrect username or password. Please try again.")

# عرض الخدمات
services = [
    "New Car ID",
    "Renew Car ID",
    "New Driving License",
    "Renew Driving License",
    "Lost ID"
]

def display_services():
    print("📋 Available Services:")
    for i, service in enumerate(services, 1):
        print(f"{i}. {service} 🚗")

# عرض الأيام
days = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday"]

def display_days():
    print("📅 Available Days:")
    for i, day in enumerate(days, 1):
        print(f"{i}. {day} 🌞")

# اختيار الخدمة واليوم والوقت
def book_service():
    display_services()
    service_choice = int(input("👉 Please select a service (1-5): "))
    selected_service = services[service_choice - 1]

    display_days()
    day_choice = int(input("👉 Please select a day (1-5): "))
    selected_day = days[day_choice - 1]

    # عرض الأوقات المتاحة
    selected_day_data = new_car_id[day_choice - 1]
    available_slots = selected_day_data[2]
    print("⏰ Available Slots:")
    for i, slot in enumerate(available_slots, 1):
        print(f"{i}. {9 + i}:00AM - Remaining: {10 - slot} bookings")

    while True:
        slot_choice = int(input("👉 Please select a slot (1-5): "))
        if available_slots[slot_choice - 1] < 10:  # تحقق من أن هناك أماكن متاحة
            selected_slot = f"{9 + slot_choice}:00AM"
            break
        else:
            print("❌ This slot is fully booked. Please select another slot.")

    # إدخال بيانات المستخدم
    full_name = input("📝 Enter your full name: ")
    id_number = input("🆔 Enter your ID number: ")

    # تأكيد الحجز
    print("\n🎉 Reservation Confirmed! 🎉")
    print(f"👤 Name: {full_name}")
    print(f"🆔 ID: {id_number}")
    print(f"🛠️ Service: {selected_service}")
    print(f"📅 Day: {selected_day}")
    print(f"⏰ Slot: {selected_slot}")

def collect_feedback():
    while True:
        try:
            print("⭐ Please rate our service (1-5): ")
            rating = int(input("Your rating: "))
            if 1 <= rating <= 5:
                print("✅ Thank you for your feedback! 😊")
                break
            else:
                print("❌ Invalid rating. Please enter a number between 1 and 5.")
        except ValueError:
            print("⚠️ Invalid input. Please enter a valid number between 1 and 5.")

def cancel_booking():
    print("❌ Cancel Booking")
    confirmation = input("Are you sure you want to cancel your booking? (yes/no): ")
    if confirmation.lower() == "yes":
        print("Your booking has been canceled.")
    else:
        print("Cancellation aborted.")

def show_statistics(service_data):
    total_reservations = sum([sum(day[2]) for day in service_data])
    print(f"📊 Total Reservations: {total_reservations}")

# تشغيل النظام
print("🚗 Welcome to the Car Licensing Booking System! 🚗")
username, password = register_user()
if login_user(username, password):
    book_service()
    collect_feedback()
    cancel_booking()
    show_statistics(new_car_id)
# Out:
# Mean of reservations for Service#1: 6.56
# Most Crowded Day for Service#1: Wednesday with 38 reservations
# Least Crowded Day for Service#1: Thursday with 27 reservations
# 🚗 Welcome to the Car Licensing Booking System! 🚗
# 🎉 Welcome to the Booking Management System! 🎉
# 👤 Enter your username: Amr Fouda
# 🔒 Enter a strong password (8 characters, mix of upper and lower case): AmrF2008
# 🔑 Confirm your password: AnrF2008
# ❌ Passwords mismatched, please try again.
# 🔒 Enter a strong password (8 characters, mix of upper and lower case): AnrF2008
# 🔑 Confirm your password: AnrF2008
# ✅ Successful Registration! 🎉
# 🔐 Please log in
# 👤 Enter your username: Amr Fouda
# 🔒 Enter your password: AnrF2008
# 🎉 Welcome Amr Fouda! 🎉
# 📋 Available Services:
# 1. New Car ID 🚗
# 2. Renew Car ID 🚗
# 3. New Driving License 🚗
# 4. Renew Driving License 🚗
# 5. Lost ID 🚗
# 👉 Please select a service (1-5): 1
# 📅 Available Days:
# 1. Sunday 🌞
# 2. Monday 🌞
# 3. Tuesday 🌞
# 4. Wednesday 🌞
# 5. Thursday 🌞
# 👉 Please select a day (1-5): 2
# ⏰ Available Slots:
# 1. 10:00AM - Remaining: 0 bookings
# 2. 11:00AM - Remaining: 8 bookings
# 3. 12:00AM - Remaining: 0 bookings
# 4. 13:00AM - Remaining: 4 bookings
# 5. 14:00AM - Remaining: 6 bookings
# 👉 Please select a slot (1-5): 1
# ❌ This slot is fully booked. Please select another slot.
# 👉 Please select a slot (1-5): 2
# 📝 Enter your full name: Amr Fouda
# 🆔 Enter your ID number: 30805078800871
#
# 🎉 Reservation Confirmed! 🎉
# 👤 Name: Amr Fouda
# 🆔 ID: 30805078800871
# 🛠️ Service: New Car ID
# 📅 Day: Monday
# ⏰ Slot: 11:00AM
# ⭐ Please rate our service (1-5):
# Your rating: 5
# ✅ Thank you for your feedback! 😊
# ❌ Cancel Booking
# Are you sure you want to cancel your booking? (yes/no): no
# Cancellation aborted.
# 📊 Total Reservations: 164
